# %%
print("Hello,world") #print ekrana çıktı veren bir koddur.
# Out:
# Hello,world

# %% [markdown]
# Python programlama dilince print komunu ekrandan ekrandan kullanıcıya bilgi veren koddur.
#
# 06.08.2024

# %%
import sys   #import python programlama dilince kütüphane eklemeye yarayan koddur.
print(sys.version )
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA

# %% [markdown]
# !pwd bize kodun çıktısını dosya yolu olarak veren kod bloğudur.
